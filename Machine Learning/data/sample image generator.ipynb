# %% [markdown]
# Sample image generator Notebook to create sample images from all classes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import operator
import os
from os.path import basename
from pathlib import Path
from shutil import copyfile

# %%
"""
Generates sample images from all classes
input
    baseDataPath: Path to the database
"""
def generateSamples(baseDataPath):
    
    sourcePath = baseDataPath + 'dataset\\training\\'
    generatePath = baseDataPath + 'samples\\'

    #create dataset root directory
    os.makedirs(Path(generatePath), exist_ok=True)
    
    imagesCreated = 0
    
    print('*Start generating images*')
    print('')
    
    #visit every class directory from the raw dataset
    for classname in Path(sourcePath).glob("*/"):
        
        classImages = ([])
        classImageCounter = 0
        numCurrentClassImages = 0

        #visit images in a class
        for file in (Path(sourcePath) / basename(classname)).glob("**/*.jpg"):
            classImages = np.append(classImages, file)
            classImageCounter += 1

        #distribute images randomly
        randomPermutation = np.random.permutation(classImageCounter)
        
        #iterate through the class images in our generated random order
        for randomIndex in np.nditer(randomPermutation):

            if(numCurrentClassImages >= 1): break
            
            #copy selected image to the sample dir
            fileToCopy = classImages.item(randomIndex)
            copyfile(fileToCopy, Path(generatePath) / (basename(classname)[:9] + ".jpg"))
            numCurrentClassImages += 1

        #after saving the image of the current class, notify user
        print('Class %s - %d image(s) saved' % ( basename(classname), numCurrentClassImages) )
    
    print('')
    print('*Completed*')
    print('---')

# %% [markdown]
# Let's generate the images.

# %%
dataPath = ''
generateSamples(dataPath)
# Out:
# *Start generating images*
#
# Class n01000001-Human - 1 image(s) saved
# Class n02000001-Abyssinian - 1 image(s) saved
# Class n02000002-Bengal - 1 image(s) saved
# Class n02000003-Birman - 1 image(s) saved
# Class n02000004-Bombay - 1 image(s) saved
# Class n02000005-British_shorthair - 1 image(s) saved
# Class n02000006-Egyptian_Mau - 1 image(s) saved
# Class n02000007-Maine_Coon - 1 image(s) saved
# Class n02000008-Persian - 1 image(s) saved
# Class n02000009-Ragdoll - 1 image(s) saved
# Class n02000010-Russian_blue - 1 image(s) saved
# Class n02000011-Siamese - 1 image(s) saved
# Class n02000012-Sphynx - 1 image(s) saved
# Class n03000001-Affenpinscher - 1 image(s) saved
# Class n03000002-Afghan_hound - 1 image(s) saved
# Class n03000003-African_hunting_dog - 1 image(s) saved
# Class n03000004-Airedale - 1 image(s) saved
# Class n03000005-Akita - 1 image(s) saved
# Class n03000006-American_bulldog - 1 image(s) saved
# Class n03000007-American_pit_bull_terrier - 1 image(s) saved
# Class n03000008-American_Staffordshire_terrier - 1 image(s) saved
# Class n03000009-Anatolian_shepherd_dog - 1 image(s) saved
# Class n03000010-Appenzeller - 1 image(s) saved
# Class n03000011-Australian_cattle_dog - 1 image(s) saved
# Class n03000012-Australian_shepherd - 1 image(s) saved
# Class n03000013-Australian_terrier - 1 image(s) saved
# Class n03000014-Basenji - 1 image(s) saved
# Class n03000015-Basset_hound - 1 image(s) saved
# Class n03000016-Beagle - 1 image(s) saved
# Class n03000017-Bearded_collie - 1 image(s) saved
# Class n03000018-Beauceron - 1 image(s) saved
# Class n03000019-Bedlington_terrier - 1 image(s) saved
# Class n03000020-Belgian_sheepdog - 1 image(s) saved
# Class n03000021-Bernese_mountain_dog - 1 image(s) saved
# Class n03000022-Bichon_frise - 1 image(s) saved
# Class n03000023-Black-and-tan_coonhound - 1 image(s) saved
# Class n03000024-Blenheim_spaniel - 1 image(s) saved
# Class n03000025-Bloodhound - 1 image(s) saved
# Class n03000026-Bluetick - 1 image(s) saved
# Class n03000027-Border_collie - 1 image(s) saved
# Class n03000028-Border_terrier - 1 image(s) saved
# Class n03000029-Borzoi - 1 image(s) saved
# Class n03000030-Boston_bull - 1 image(s) saved
# Class n03000031-Bouvier_des_Flandres - 1 image(s) saved
# Class n03000032-Boxer - 1 image(s) saved
# Class n03000033-Boykin_spaniel - 1 image(s) saved
# Class n03000034-Brabancon_griffon - 1 image(s) saved
# Class n03000035-Briard - 1 image(s) saved
# Class n03000036-Brittany_spaniel - 1 image(s) saved
# Class n03000037-Brussels_griffon - 1 image(s) saved
# Class n03000038-Bull_mastiff - 1 image(s) saved
# Class n03000039-Bull_terrier - 1 image(s) saved
# Class n03000040-Cairn - 1 image(s) saved
# Class n03000041-Canaan_dog - 1 image(s) saved
# Class n03000042-Cane_corso - 1 image(s) saved
# Class n03000043-Cardigan_Welsh_Corgi - 1 image(s) saved
# Class n03000044-Cavalier_king_charles_spaniel - 1 image(s) saved
# Class n03000045-Chesapeake_Bay_retriever - 1 image(s) saved
# Class n03000046-Chihuahua - 1 image(s) saved
# Class n03000047-Chinese_shar-pei - 1 image(s) saved
# Class n03000048-Chow - 1 image(s) saved
# Class n03000049-Clumber - 1 image(s) saved
# Class n03000050-Cocker_spaniel - 1 image(s) saved
# Class n03000051-Collie - 1 image(s) saved
# Class n03000052-Curly-coated_retriever - 1 image(s) saved
# Class n03000053-Dachshund - 1 image(s) saved
# Class n03000054-Dalmatian - 1 image(s) saved
# Class n03000055-Dandie_Dinmont - 1 image(s) saved
# Class n03000056-Dhole - 1 image(s) saved
# Class n03000057-Dingo - 1 image(s) saved
# Class n03000058-Doberman - 1 image(s) saved
# Class n03000059-Dogue_de_bordeaux - 1 image(s) saved
# Class n03000060-English_cocker_spaniel - 1 image(s) saved
# Class n03000061-English_setter - 1 image(s) saved
# Class n03000062-English_springer - 1 image(s) saved
# Class n03000063-Entlebucher_mountain_dog - 1 image(s) saved
# Class n03000064-Eskimo_dog - 1 image(s) saved
# Class n03000065-Flat-coated_retriever - 1 image(s) saved
# Class n03000066-Foxhound - 1 image(s) saved
# Class n03000067-French_bulldog - 1 image(s) saved
# Class n03000068-German_shepherd - 1 image(s) saved
# Class n03000069-German_shorthaired - 1 image(s) saved
# Class n03000070-Giant_schnauzer - 1 image(s) saved
# Class n03000071-Golden_retriever - 1 image(s) saved
# Class n03000072-Gordon_setter - 1 image(s) saved
# Class n03000073-Greater_Swiss_Mountain_dog - 1 image(s) saved
# Class n03000074-Great_Dane - 1 image(s) saved
# Class n03000075-Great_pyrenees - 1 image(s) saved
# Class n03000076-Groenendael - 1 image(s) saved
# Class n03000077-Havanese - 1 image(s) saved
# Class n03000078-Ibizan_hound - 1 image(s) saved
# Class n03000079-Irish_setter - 1 image(s) saved
# Class n03000080-Irish_terrier - 1 image(s) saved
# Class n03000081-Irish_water_spaniel - 1 image(s) saved
# Class n03000082-Irish_wolfhound - 1 image(s) saved
# Class n03000083-Italian_greyhound - 1 image(s) saved
# Class n03000084-Japanese_chin - 1 image(s) saved
# Class n03000085-Keeshond - 1 image(s) saved
# Class n03000086-Kelpie - 1 image(s) saved
# Class n03000087-Kerry_blue_terrier - 1 image(s) saved
# Class n03000088-Komondor - 1 image(s) saved
# Class n03000089-Kuvasz - 1 image(s) saved
# Class n03000090-Labrador_retriever - 1 image(s) saved
# Class n03000091-Lakeland_terrier - 1 image(s) saved
# Class n03000092-Leonberger - 1 image(s) saved
# Class n03000093-Lhasa_Apso - 1 image(s) saved
# Class n03000094-Malamute - 1 image(s) saved
# Class n03000095-Malinois - 1 image(s) saved
# Class n03000096-Maltese_dog - 1 image(s) saved
# Class n03000097-Mexican_hairless - 1 image(s) saved
# Class n03000098-Miniature_pinscher - 1 image(s) saved
# Class n03000099-Miniature_poodle - 1 image(s) saved
# Class n03000100-Miniature_schnauzer - 1 image(s) saved
# Class n03000101-Newfoundland - 1 image(s) saved
# Class n03000102-Norfolk_terrier - 1 image(s) saved
# Class n03000103-Norwegian_elkhound - 1 image(s) saved
# Class n03000104-Norwich_terrier - 1 image(s) saved
# Class n03000105-Nova_scotia_duck_tolling_retriever - 1 image(s) saved
# Class n03000106-Old_English_sheepdog - 1 image(s) saved
# Class n03000107-Otterhound - 1 image(s) saved
# Class n03000108-Papillon - 1 image(s) saved
# Class n03000109-Pekingese - 1 image(s) saved
# Class n03000110-Pembroke_Welsh_Corgi - 1 image(s) saved
# Class n03000111-Pomeranian - 1 image(s) saved
# Class n03000112-Pug - 1 image(s) saved
# Class n03000113-Redbone - 1 image(s) saved
# Class n03000114-Rhodesian_ridgeback - 1 image(s) saved
# Class n03000115-Rottweiler - 1 image(s) saved
# Class n03000116-Saint_Bernard - 1 image(s) saved
# Class n03000117-Saluki - 1 image(s) saved
# Class n03000118-Samoyed - 1 image(s) saved
# Class n03000119-Schipperke - 1 image(s) saved
# Class n03000120-Scottish_deerhound - 1 image(s) saved
# Class n03000121-Scottish_terrier - 1 image(s) saved
# Class n03000122-Sealyham_terrier - 1 image(s) saved
# Class n03000123-Shetland_sheepdog - 1 image(s) saved
# Class n03000124-Shiba_Inu - 1 image(s) saved
# Class n03000125-Shih-Tzu - 1 image(s) saved
# Class n03000126-Siberian_husky - 1 image(s) saved
# Class n03000127-Silky_terrier - 1 image(s) saved
# Class n03000128-Soft-coated_wheaten_terrier - 1 image(s) saved
# Class n03000129-Staffordshire_bull_terrier - 1 image(s) saved
# Class n03000130-Standard_poodle - 1 image(s) saved
# Class n03000131-Standard_schnauzer - 1 image(s) saved
# Class n03000132-Sussex_spaniel - 1 image(s) saved
# Class n03000133-Tibetan_mastiff - 1 image(s) saved
# Class n03000134-Tibetan_terrier - 1 image(s) saved
# Class n03000135-Toy_poodle - 1 image(s) saved
# Class n03000136-Toy_terrier - 1 image(s) saved
# Class n03000137-Vizsla - 1 image(s) saved
# Class n03000138-Walker_hound - 1 image(s) saved
# Class n03000139-Weimaraner - 1 image(s) saved
# Class n03000140-Welsh_springer_spaniel - 1 image(s) saved
# Class n03000141-West_Highland_white_terrier - 1 image(s) saved
# Class n03000142-Wheaten_terrier - 1 image(s) saved
# Class n03000143-Whippet - 1 image(s) saved
# Class n03000144-Wire-haired_fox_terrier - 1 image(s) saved
# Class n03000145-Yorkshire_terrier - 1 image(s) saved
#
# *Completed*
# ---
